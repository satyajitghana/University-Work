% %%
%%file fourier_series.m
function[] = fourier_series(f, K, T, precision)
    syms x;
    w = (2*pi)/T;
    n = 1:K;
    
    %% calculate the constants
    a0 = (2/T)*int(f, x, 0, 2*pi);
    an = (2/T)*int(f*cos(n*w*x), x, 0, 2*pi);
    bn = (2/T)*int(f*sin(n*w*x), x, 0, 2*pi);
    v1 = [a0, an, bn];
    v2 = [1/2 cos(n*w*x) sin(n*w*x)];
    
    FS = v1.*v2;
    
    %% fouriere transform
    FS = sum(FS);
    FS = vpa(FS);
    
    disp('Fourier Transformed Equation : ');
    disp(FS);
    
    %%x = linspace(0, T, 500);
    %%y = eval(FS);
    %%plot(x, y, 'r');
    fplot(sym(FS), [0 4*pi], 'LineWidth', 2);
    hold on;
    
    x = linspace(0, T, 500);
    y = f(x);
    ry = repmat(y, 1, 2);
    rx = linspace(0, 4*pi, length(ry));
    plot(rx, ry, 'LineWidth', 2);
end
% Out:
% Created file 'C:\Users\shadowleaf\MATLAB\fourier_series.m'.

% %%
fourier_series(@(x) x.^2, 10, 2*pi, 100);
% Out:
% Fourier Transformed Equation :
% 1.0000000000000000618223860751221*cos(2.0*x) + 0.25000000000000001545559651878053*cos(4.0*x) + 0.062500000000000003863899129695132*cos(8.0*x) + 0.04938271604938271910234005309245*cos(9.0*x) - 6.2831853071795868653667946085502*sin(2.0*x) - 3.1415926535897934326833973042751*sin(4.0*x) - 1.5707963267948967163416986521375*sin(8.0*x) + 0.16000000000000000989158177201954*cos(5.0*x) + 0.040000000000000002472895443004885*cos(10.0*x) - 1.3962634015954637478592876907889*sin(9.0*x) - 2.5132741228718347461467178434201*sin(5.0*x) - 1.25663706143591737307335892171*sin(10.0*x) + 0.44444444444444447192106047783205*cos(3.0*x) + 0.11111111111111111798026511945801*cos(6.0*x) - 4.1887902047863912435778630723668*sin(3.0*x) - 2.0943951023931956217889315361834*sin(6.0*x) + 0.081632653061224494842643761234459*cos(7.0*x) - 1.7951958020513105329619413167286*sin(7.0*x) + 4.0000000000000002472895443004885*cos(x) - 12.5663706143591737307335892171*sin(x) + 13.159472534785812305329312923663

% %%
fourier_series(@(x) x.^5, 10, 2*pi, 100);
% Out:
% Fourier Transformed Equation :
% 573.00164380214954035691549540893*cos(2.0*x) + 152.08614028875867911865092877051*cos(4.0*x) + 38.573768155828500656501610625018*cos(8.0*x) + 30.508564342551637972052723069386*cos(9.0*x) - 1368.6533685222519080197724548208*sin(2.0*x) - 754.83309226929614801001928656065*sin(4.0*x) - 386.55943697941934827540230624086*sin(8.0*x) + 98.013713797980950017396208230847*cos(5.0*x) + 24.72962312055370263150225666362*cos(10.0*x) - 344.18133089015500468113277346576*sin(9.0*x) - 610.86188898422125704604952008878*sin(5.0*x) - 310.13235460463352095071770679821*sin(10.0*x) + 266.3029255920286602796787287161*cos(3.0*x) + 68.321060650001494754743791792511*cos(6.0*x) - 981.53141408463232778239046792045*sin(3.0*x) - 512.23519830399622140849298416859*sin(6.0*x) + 50.308464119081112943856980350559*cos(7.0*x) - 440.70908453739127411773579556805*sin(7.0*x) + 1726.5198975624353435446504668662*cos(x) - 1777.9542089137807224699436134145*sin(x) + 1632.1049855215011849685781836068

% %%
fourier_series(@(x) sin(x), 10, 2*pi, 100);
% Out:
% Fourier Transformed Equation :
% 1.0000000000000000618223860751221*sin(x)

% %%
fourier_series(@(x) tan(x), 10, 2*pi, 100);
% Out:
% Fourier Transformed Equation :
% NaN

% %%
fourier_series(@(x) csc(x), 10, 2*pi, 100);
% Out:
% Fourier Transformed Equation :
% NaN

% %%
fourier_series(@(x) x.^2+x+1, 10, 2*pi, 100);
% Out:
% Fourier Transformed Equation :
% 1.0000000000000000618223860751221*cos(2.0*x) + 0.25000000000000001545559651878053*cos(4.0*x) + 0.062500000000000003863899129695132*cos(8.0*x) + 0.04938271604938271910234005309245*cos(9.0*x) - 7.2831853071795869271891806836723*sin(2.0*x) - 3.6415926535897934635945903418361*sin(4.0*x) - 1.8207963267948967317972951709181*sin(8.0*x) + 0.16000000000000000989158177201954*cos(5.0*x) + 0.040000000000000002472895443004885*cos(10.0*x) - 1.618485623817685983819817929705*sin(9.0*x) - 2.9132741228718347708756722734689*sin(5.0*x) - 1.4566370614359173854378361367345*sin(10.0*x) + 0.44444444444444447192106047783205*cos(3.0*x) + 0.11111111111111111798026511945801*cos(6.0*x) - 4.8554568714530579514594537891149*sin(3.0*x) - 2.4277284357265289757297268945574*sin(6.0*x) + 0.081632653061224494842643761234459*cos(7.0*x) - 2.0809100877655962649111944810492*sin(7.0*x) + 4.0000000000000002472895443004885*cos(x) - 14.566370614359173854378361367345*sin(x) + 17.30106518837560579983509630306
